# %%
import random, pandas as pd
import numpy as np
from datetime import datetime

# %%
target_dir ='./data/'
cols = ['time', 'measurement_values','predict_values', 'upper_values', 'lower_values']
df = pd.DataFrame(columns=cols)

# %%
df = pd.DataFrame(columns=cols)
df.time = [datetime.strftime(d , '%Y-%m-%d %H:%M') for d in pd.date_range(start='2021-09-01 12:00', end='2022-10-01 12:00', freq='60min')]
df.measurement_values = [random.uniform(0, 15) for i in range(len(df))]
df.predict_values = [random.uniform(6, 9) for i in range(len(df))]
df.upper_values = [random.uniform(10, 13) for i in range(len(df))]
df.lower_values = [random.uniform(0, 5) for i in range(len(df))]

# %%
# df.to_csv('./data/demo4.csv', index=False)

# %%
df_test = df.head(100)
df_test.loc[90:, 'measurement_values'] = None
df_test.replace([np.nan],[None])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                 time measurement_values predict_values upper_values  \
# 0   2021-09-01 12:00          13.425594       6.063691    11.752684
# 1   2021-09-01 13:00           3.000849       7.337809    10.276908
# 2   2021-09-01 14:00          12.338376       8.117069    12.163874
# 3   2021-09-01 15:00          12.068836       7.129938    11.093922
# 4   2021-09-01 16:00           6.315243       8.350015    12.829897
# ..               ...                ...            ...          ...
# 95  2021-09-05 11:00               None       8.228439    11.375634
# ...
